# %% [markdown]
# ## Doing Fig4 of Deep's paper

# %%
          |  Deep: hasNS   |  Deep: hasREM  ||   RF: hasNS    |   RF: hasREM  ||  KNN: hasNS    |   KNN: hasREM
Threshold |  TP     FP     |  TP     FP     ||  TP     FP     |  TP     FP    ||  TP    FP      |   TP   FP           
0.07      |  0.999  0.144  |  0.995  0.106  ||  0.999  0.118  |  0.998  0.033 ||  1.000  0.000  |   0.994  0.090
0.27      |  0.995  0.096  |  0.979  0.040  ||  0.994  0.076  |  0.992  0.015 ||  0.998  0.134  |   0.981  0.040
0.51      |  0.986  0.061  |  0.949  0.014  ||  0.984  0.048  |  0.981  0.009 ||  0.990  0.072  |   0.953  0.014
0.80      |  0.959  0.028  |  0.894  0.003  ||  0.961  0.020  |  0.959  0.004 ||  0.981  0.053  |   0.904  0.004
0.94      |  0.900  0.010  |  0.822  0.001  ||  0.925  0.007  |  0.925  0.002 ||  0.965  0.034  |   0.850  0.001

# %% [markdown]
# # KNN

# %%
import KNNclassy
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text',usetex=True)
rc('font',family='serif')

# %%
import importlib
importlib.reload(KNNclassy)
# Out:
# <module 'KNNclassy' from '/Users/miquelmiravet/Projects/IPAM_LA/ML_group/KNN_miq/KNNclassy.py'>

# %%
path = '/Users/miquelmiravet/Projects/IPAM_LA/ML_group/KNN_miq/'

# %%
KNN_REM = KNNclassy.ClassificationKNN('REM')
KNN_REM.load_datasets(path)
modelKNN_REM = KNN_REM.build_model()
fitmodelKNN_REM = modelKNN_REM.fit(KNN_REM.xtrain,KNN_REM.ytrain.ravel())

KNN_NS = KNNclassy.ClassificationKNN('NS')
KNN_NS.load_datasets(path)
modelKNN_NS = KNN_NS.build_model()
fitmodelKNN_NS = modelKNN_NS.fit(KNN_NS.xtrain,KNN_NS.ytrain.ravel())
# Out:
# File shape :  (139999, 20)
# File shape :  (59999, 20)
# xtrain shape :  (139999, 5)
# xtest shape :  (59999, 5)
# File shape :  (139999, 20)
# File shape :  (59999, 20)
# xtrain shape :  (139999, 5)
# xtest shape :  (59999, 5)

# %%
def generateMasses(algo,N):
    data=algo.xtest
    maxm1=np.max(data[:,0])
    minm1=np.min(data[:,0])
    maxm2=np.max(data[:,1])
    minm2=np.min(data[:,1])
    print("Trained with m1 in (",minm1,",",maxm1,")")
    print("Trained with m2 in (",minm2,",",maxm2,")")
    m1=np.linspace(start=minm1, stop=maxm1, num=N)
    m2=np.linspace(start=minm2, stop=maxm2, num=N)
    masses = []
    for i in range(0,N):
        for j in range(0,N):
            if(m1[i]>m2[j]):
                masses.append([m1[i],m2[j]])

    return masses

def generateMasses_limited(N):
    maxm1=50
    minm1=1
    maxm2=12
    minm2=1
    m1=np.linspace(start=minm1, stop=maxm1, num=N)
    m2=np.linspace(start=minm2, stop=maxm2, num=N)
    masses=[]
    for i in range(0,N):
        for j in range(0,N):
            if(m1[i]>m2[j]):
                masses.append([m1[i],m2[j]])

    return masses

        
def probLabelDensePlot(model, masses, chi1, chi2, snr,label):
    N=len(masses)
    X=[]
    m1=np.zeros(N)
    m2=np.zeros(N)
    for k in range(0,N):
        X.append([masses[k][0],masses[k][1],chi1,chi2,snr])
        m1[k]=masses[k][0]
        m2[k]=masses[k][1]
    proba_dense   = model.predict_proba(X)
    proba_dense1d = proba_dense[:,1]
    plt.figure(figsize = (10,2.4))
    plt.tick_params(axis='y',labelsize=13)
    plt.tick_params(axis='x',labelsize=13)
    sc=plt.scatter(m1,m2, c=proba_dense1d, vmin=0, vmax=1, s=40, cmap='viridis')
    cbar = plt.colorbar(sc)
    cbar.ax.tick_params(labelsize=13)
    if label == 'NS':
        plt.axhline(y = 3, color = 'r', linestyle = '-')
    plt.title(r'$\chi^z_1$ = '+str(chi1)+', $\chi^z_2$ = '+str(chi2)+', SNR='+str(snr),fontsize=18)
    plt.xlabel(r"$m_1$", fontsize=18)
    plt.xlim([1,50])
    plt.ylim([1,12])
    plt.ylabel(r"$m_2$", fontsize=18)
    plt.show()
    return

# %%
M_l=generateMasses_limited(200)

# %%
probLabelDensePlot(modelKNN_REM,M_l,0,0,11,KNN_REM.label)
probLabelDensePlot(modelKNN_REM,M_l,0,0.9,11,KNN_REM.label)
probLabelDensePlot(modelKNN_REM,M_l,0.9,0,11,KNN_REM.label)
probLabelDensePlot(modelKNN_REM,M_l,0.9,0.9,11,KNN_REM.label)

# %%
probLabelDensePlot(modelKNN_NS,M_l,0,0,11,KNN_NS.label)
probLabelDensePlot(modelKNN_NS,M_l,0,0.9,11,KNN_NS.label)
probLabelDensePlot(modelKNN_NS,M_l,0.9,0,11,KNN_NS.label)
probLabelDensePlot(modelKNN_NS,M_l,0.9,0.9,11,KNN_NS.label)

# %% [markdown]
# Figure 6 (extension to see variation with SNR)

# %%
probLabelDensePlot(modelKNN_NS,M_l,0,0,5,KNN_NS.label)
probLabelDensePlot(modelKNN_NS,M_l,0,0,7,KNN_NS.label)
probLabelDensePlot(modelKNN_NS,M_l,0,0,9,KNN_NS.label)
probLabelDensePlot(modelKNN_NS,M_l,0,0,11,KNN_NS.label)

# %%
probLabelDensePlot(modelKNN_REM,M_l,0,0,5,KNN_REM.label)
probLabelDensePlot(modelKNN_REM,M_l,0,0,7,KNN_REM.label)
probLabelDensePlot(modelKNN_REM,M_l,0,0,9,KNN_REM.label)
probLabelDensePlot(modelKNN_REM,M_l,0,0,11,KNN_REM.label)

# %% [markdown]
# # RF

# %%
import classyRF

# %%
importlib.reload(classyRF)
from sklearn.ensemble import _forest

# %%
i_m1i=1; i_m2i=2; i_x1i=3; i_x2i=4; i_mci=5; i_qi=6; i_Ri=7; i_Ci=8; 
i_m1r=9; i_m2r=10; i_x1r=11; i_x2r=12; i_mcr=13; i_qr=15; i_Rr=16; i_Cr=17;
i_snr=18;
injected_index = [i_m1i-1, i_m2i-1, i_x1i-1, i_x2i-1, i_mci-1, i_qi-1, i_Ri-1, i_Ci-1, i_snr-1]
recovered_index = [i_m1r-1, i_m2r-1, i_x1r-1, i_x2r-1, i_mcr-1, i_qr-1, i_Rr-1, i_Cr-1, i_snr-1]
independent_injected_index = [i_m1i, i_m2i, i_x1i, i_x2i, i_snr]
independent_recovered_index = [i_m1r, i_m2r, i_x1r, i_x2r, i_snr]

# %%
path = '/Users/miquelmiravet/Projects/IPAM_LA/ML_group/KNN_miq/ipam_REM_set/'
RF = classyRF.ClassificationRF()
RF.load_train_dataset(path, fname_x='train_REM.csv')
RF.load_test_dataset(path, fname_x='test_REM.csv')
RF.loadModel(path, 'REM_ind_rec_crossvalidated')
RF.subset_features(independent_recovered_index)
# Out:
# loading  /Users/miquelmiravet/Projects/IPAM_LA/ML_group/KNN_miq/ipam_REM_set/REM_ind_rec_crossvalidated.joblib
# Training and testing using:
# m1_rec
# m2_rec
# chi1_rec
# chi2_rec
# snr

# %%
path = '/Users/miquelmiravet/Projects/IPAM_LA/ML_group/KNN_miq/ipam_NS_set/'
RFns = classyRF.ClassificationRF()
RFns.load_train_dataset(path, fname_x='train_NS.csv')
RFns.load_test_dataset(path, fname_x='test_NS.csv')
RFns.loadModel(path, 'ind_rec_crossvalidated')
RFns.subset_features(independent_recovered_index)
# Out:
# loading  /Users/miquelmiravet/Projects/IPAM_LA/ML_group/KNN_miq/ipam_NS_set/ind_rec_crossvalidated.joblib
# Training and testing using:
# m1_rec
# m2_rec
# chi1_rec
# chi2_rec
# snr

# %%
M_l=generateMasses_limited(200)

# %%
probLabelDensePlot(RF.model,M_l,0,0,11,'REM')
probLabelDensePlot(RF.model,M_l,0,0.9,11,'REM')
probLabelDensePlot(RF.model,M_l,0.9,0,11,'REM')
probLabelDensePlot(RF.model,M_l,0.9,0.9,11,'REM')

# %%
probLabelDensePlot(RFns.model,M_l,0,0,11,'NS')
probLabelDensePlot(RFns.model,M_l,0,0.9,11,'NS')
probLabelDensePlot(RFns.model,M_l,0.9,0,11,'NS')
probLabelDensePlot(RFns.model,M_l,0.9,0.9,11,'NS')

# %%
probLabelDensePlot(RF.model,M_l,0,0,5,'REM')
probLabelDensePlot(RF.model,M_l,0,0,7,'REM')
probLabelDensePlot(RF.model,M_l,0,0,9,'REM')
probLabelDensePlot(RF.model,M_l,0,0,11,'REM')

# %%
probLabelDensePlot(RFns.model,M_l,0,0,5,'NS')
probLabelDensePlot(RFns.model,M_l,0,0,7,'NS')
probLabelDensePlot(RFns.model,M_l,0,0,9,'NS')
probLabelDensePlot(RFns.model,M_l,0,0,11,'NS')
