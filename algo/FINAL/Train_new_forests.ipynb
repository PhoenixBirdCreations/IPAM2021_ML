# %%
import classyRF_final as classyRF
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import warnings
warnings.filterwarnings('ignore')

# %%
import importlib
importlib.reload(classyRF)
# Out:
# <module 'classyRF_final' from 'C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\classyRF_final.py'>

# %%
pathClassy = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\classy_RF\\"
pathData = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\allEOS\\"
pathMDC = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\"

# %%
i_m1r=1; i_m2r=2; i_x1r=3; i_x2r=4; i_mcr=5; i_qr=6; i_Rr=7;
i_snr=8;
recovered_index = [i_m1r, i_m2r, i_x1r, i_x2r, i_mcr, i_qr, i_Rr, i_snr]
independent_recovered_index = [i_m1r, i_m2r, i_x1r, i_x2r, i_snr]
independent_recovered_karoo = [0, 1, 2, 3, 7]

# %%
EOS = ["APR4_EPP", "BHF_BBB2", "H4", "HQC18", "KDE0V", "KDE0V1", "MPA1", "MS1_PP", "MS1B_PP", "RS", "SK255", "SK272", "SKI2", "SKI3", "SKI4", "SKI5", "SKI6", "SKMP", "SKOP", "SLy", "SLY2", "SLY9", "SLY230A"]
BayesFactor=[1.526, 1.555, 0.056, 1.422, 1.177, 1.283, 0.276, 0.001, 0.009, 0.176, 0.179, 0.159, 0.108, 0.107, 0.33, 0.025, 0.288, 0.29, 0.618, 1.0, 1.028, 0.37, 0.932]
EOSTest = ["APR4_EPP", "BHF_BBB2"]
EOScolor = ['BHF_BBB2', 'SLy', 'MS1B_PP']

# %%
pathTrees = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\Forest_O2_70-30_50trees_15depth\\"
for eos in EOS:
    print("-------------------------------")
    print("Doing", eos)
    RF = classyRF.ClassificationRF()
    RF.load_test_dataset(pathData+eos+'\\EMB\\', 'test_EMB_ID_LABEL_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_test
    RF.load_test_dataset(pathData+eos+'\\NS\\', 'test_NS_ID_LABEL_'+eos+'_s300_f0d7.csv')
    RF.labels_test = RF.labels_test + aux
    
    RF.load_train_dataset(pathData+eos+'\\EMB\\', 'train_EMB_karoo_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_train
    RF.load_train_dataset(pathData+eos+'\\NS\\', 'train_NS_karoo_'+eos+'_s300_f0d7.csv')
    RF.labels_train = RF.labels_train + aux
 
    RF.subset_test(independent_recovered_index)
    RF.subset_train(independent_recovered_karoo)
    
    RF.train(trees=50, criterion='entropy', features=5, max_depth=15)
    
    RF.saveModel(pathTrees, eos)
# Out:
# -------------------------------
# Doing APR4_EPP
# -------------------------------
# Doing BHF_BBB2
# -------------------------------
# Doing H4
# -------------------------------
# Doing HQC18
# -------------------------------
# Doing KDE0V
# -------------------------------
# Doing KDE0V1
# -------------------------------
# Doing MPA1
# -------------------------------
# Doing MS1_PP
# -------------------------------
# Doing MS1B_PP
# -------------------------------
# Doing RS
# -------------------------------
# Doing SK255
# -------------------------------
# Doing SK272
# -------------------------------
# Doing SKI2
# -------------------------------
# Doing SKI3
# -------------------------------
# Doing SKI4
# -------------------------------
# Doing SKI5
# -------------------------------
# Doing SKI6
# -------------------------------
# Doing SKMP
# -------------------------------
# Doing SKOP
# -------------------------------
# Doing SLy
# -------------------------------
# ...

# %%
pathTrees = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\Forest_O2_70-30_100trees_15depth\\"
for eos in EOS:
    print("-------------------------------")
    print("Doing", eos)
    RF = classyRF.ClassificationRF()
    RF.load_test_dataset(pathData+eos+'\\EMB\\', 'test_EMB_ID_LABEL_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_test
    RF.load_test_dataset(pathData+eos+'\\NS\\', 'test_NS_ID_LABEL_'+eos+'_s300_f0d7.csv')
    RF.labels_test = RF.labels_test + aux
    
    RF.load_train_dataset(pathData+eos+'\\EMB\\', 'train_EMB_karoo_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_train
    RF.load_train_dataset(pathData+eos+'\\NS\\', 'train_NS_karoo_'+eos+'_s300_f0d7.csv')
    RF.labels_train = RF.labels_train + aux
 
    RF.subset_test(independent_recovered_index)
    RF.subset_train(independent_recovered_karoo)
    
    RF.train(trees=100, criterion='entropy', features=5, max_depth=15)
    
    RF.saveModel(pathTrees, eos)
# Out:
# -------------------------------
# Doing APR4_EPP
# -------------------------------
# Doing BHF_BBB2
# -------------------------------
# Doing H4
# -------------------------------
# Doing HQC18
# -------------------------------
# Doing KDE0V
# -------------------------------
# Doing KDE0V1
# -------------------------------
# Doing MPA1
# -------------------------------
# Doing MS1_PP
# -------------------------------
# Doing MS1B_PP
# -------------------------------
# Doing RS
# -------------------------------
# Doing SK255
# -------------------------------
# Doing SK272
# -------------------------------
# Doing SKI2
# -------------------------------
# Doing SKI3
# -------------------------------
# Doing SKI4
# -------------------------------
# Doing SKI5
# -------------------------------
# Doing SKI6
# -------------------------------
# Doing SKMP
# -------------------------------
# Doing SKOP
# -------------------------------
# Doing SLy
# -------------------------------
# ...

# %%
pathTrees = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\Forest_O2_70-30_100trees_Nonedepth\\"
for eos in EOS:
    print("-------------------------------")
    print("Doing", eos)
    RF = classyRF.ClassificationRF()
    RF.load_test_dataset(pathData+eos+'\\EMB\\', 'test_EMB_ID_LABEL_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_test
    RF.load_test_dataset(pathData+eos+'\\NS\\', 'test_NS_ID_LABEL_'+eos+'_s300_f0d7.csv')
    RF.labels_test = RF.labels_test + aux
    
    RF.load_train_dataset(pathData+eos+'\\EMB\\', 'train_EMB_karoo_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_train
    RF.load_train_dataset(pathData+eos+'\\NS\\', 'train_NS_karoo_'+eos+'_s300_f0d7.csv')
    RF.labels_train = RF.labels_train + aux
 
    RF.subset_test(independent_recovered_index)
    RF.subset_train(independent_recovered_karoo)
    
    RF.train(trees=100, criterion='entropy', features=5, max_depth=None)
    
    RF.saveModel(pathTrees, eos)
# Out:
# -------------------------------
# Doing APR4_EPP
# -------------------------------
# Doing BHF_BBB2
# -------------------------------
# Doing H4
# -------------------------------
# Doing HQC18
# -------------------------------
# Doing KDE0V
# -------------------------------
# Doing KDE0V1
# -------------------------------
# Doing MPA1
# -------------------------------
# Doing MS1_PP
# -------------------------------
# Doing MS1B_PP
# -------------------------------
# Doing RS
# -------------------------------
# Doing SK255
# -------------------------------
# Doing SK272
# -------------------------------
# Doing SKI2
# -------------------------------
# Doing SKI3
# -------------------------------
# Doing SKI4
# -------------------------------
# Doing SKI5
# -------------------------------
# Doing SKI6
# -------------------------------
# Doing SKMP
# -------------------------------
# Doing SKOP
# -------------------------------
# Doing SLy
# -------------------------------
# ...

# %%
pathTrees = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\Forest_O2_70-30_50trees_Nonedepth\\"
for eos in EOS:
    print("-------------------------------")
    print("Doing", eos)
    RF = classyRF.ClassificationRF()
    RF.load_test_dataset(pathData+eos+'\\EMB\\', 'test_EMB_ID_LABEL_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_test
    RF.load_test_dataset(pathData+eos+'\\NS\\', 'test_NS_ID_LABEL_'+eos+'_s300_f0d7.csv')
    RF.labels_test = RF.labels_test + aux
    
    RF.load_train_dataset(pathData+eos+'\\EMB\\', 'train_EMB_karoo_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_train
    RF.load_train_dataset(pathData+eos+'\\NS\\', 'train_NS_karoo_'+eos+'_s300_f0d7.csv')
    RF.labels_train = RF.labels_train + aux
 
    RF.subset_test(independent_recovered_index)
    RF.subset_train(independent_recovered_karoo)
    
    RF.train(trees=50, criterion='entropy', features=5, max_depth=None)
    
    RF.saveModel(pathTrees, eos)
# Out:
# -------------------------------
# Doing APR4_EPP
# -------------------------------
# Doing BHF_BBB2
# -------------------------------
# Doing H4
# -------------------------------
# Doing HQC18
# -------------------------------
# Doing KDE0V
# -------------------------------
# Doing KDE0V1
# -------------------------------
# Doing MPA1
# -------------------------------
# Doing MS1_PP
# -------------------------------
# Doing MS1B_PP
# -------------------------------
# Doing RS
# -------------------------------
# Doing SK255
# -------------------------------
# Doing SK272
# -------------------------------
# Doing SKI2
# -------------------------------
# Doing SKI3
# -------------------------------
# Doing SKI4
# -------------------------------
# Doing SKI5
# -------------------------------
# Doing SKI6
# -------------------------------
# Doing SKMP
# -------------------------------
# Doing SKOP
# -------------------------------
# Doing SLy
# -------------------------------
# ...

# %%
pathTrees = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\Forest_O2_70-30_200trees_15depth\\"
for eos in EOS:
    print("-------------------------------")
    print("Doing", eos)
    RF = classyRF.ClassificationRF()
    RF.load_test_dataset(pathData+eos+'\\EMB\\', 'test_EMB_ID_LABEL_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_test
    RF.load_test_dataset(pathData+eos+'\\NS\\', 'test_NS_ID_LABEL_'+eos+'_s300_f0d7.csv')
    RF.labels_test = RF.labels_test + aux
    
    RF.load_train_dataset(pathData+eos+'\\EMB\\', 'train_EMB_karoo_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_train
    RF.load_train_dataset(pathData+eos+'\\NS\\', 'train_NS_karoo_'+eos+'_s300_f0d7.csv')
    RF.labels_train = RF.labels_train + aux
 
    RF.subset_test(independent_recovered_index)
    RF.subset_train(independent_recovered_karoo)
    
    RF.train(trees=200, criterion='entropy', features=5, max_depth=15)
    
    RF.saveModel(pathTrees, eos)
# Out:
# -------------------------------
# Doing APR4_EPP
# -------------------------------
# Doing BHF_BBB2
# -------------------------------
# Doing H4
# -------------------------------
# Doing HQC18
# -------------------------------
# Doing KDE0V
# -------------------------------
# Doing KDE0V1
# -------------------------------
# Doing MPA1
# -------------------------------
# Doing MS1_PP
# -------------------------------
# Doing MS1B_PP
# -------------------------------
# Doing RS
# -------------------------------
# Doing SK255
# -------------------------------
# Doing SK272
# -------------------------------
# Doing SKI2
# -------------------------------
# Doing SKI3
# -------------------------------
# Doing SKI4
# -------------------------------
# Doing SKI5
# -------------------------------
# Doing SKI6
# -------------------------------
# Doing SKMP
# -------------------------------
# Doing SKOP
# -------------------------------
# Doing SLy
# -------------------------------
# ...

# %%
pathTrees = "C:\\Users\\marin\\Desktop\\ML_workingGroup\\FINAL\\Forest_O2_70-30_200trees_Nonedepth\\"
for eos in EOS:
    print("-------------------------------")
    print("Doing", eos)
    RF = classyRF.ClassificationRF()
    RF.load_test_dataset(pathData+eos+'\\EMB\\', 'test_EMB_ID_LABEL_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_test
    RF.load_test_dataset(pathData+eos+'\\NS\\', 'test_NS_ID_LABEL_'+eos+'_s300_f0d7.csv')
    RF.labels_test = RF.labels_test + aux
    
    RF.load_train_dataset(pathData+eos+'\\EMB\\', 'train_EMB_karoo_'+eos+'_s300_f0d7.csv')
    aux = RF.labels_train
    RF.load_train_dataset(pathData+eos+'\\NS\\', 'train_NS_karoo_'+eos+'_s300_f0d7.csv')
    RF.labels_train = RF.labels_train + aux
 
    RF.subset_test(independent_recovered_index)
    RF.subset_train(independent_recovered_karoo)
    
    RF.train(trees=200, criterion='entropy', features=5, max_depth=None)
    
    RF.saveModel(pathTrees, eos)
# Out:
# -------------------------------
# Doing APR4_EPP
# -------------------------------
# Doing BHF_BBB2
# -------------------------------
# Doing H4
# -------------------------------
# Doing HQC18
# -------------------------------
# Doing KDE0V
# -------------------------------
# Doing KDE0V1
# -------------------------------
# Doing MPA1
# -------------------------------
# Doing MS1_PP
# -------------------------------
# Doing MS1B_PP
# -------------------------------
# Doing RS
# -------------------------------
# Doing SK255
# -------------------------------
# Doing SK272
# -------------------------------
# Doing SKI2
# -------------------------------
# Doing SKI3
# -------------------------------
# Doing SKI4
# -------------------------------
# Doing SKI5
# -------------------------------
# Doing SKI6
# -------------------------------
# Doing SKMP
# -------------------------------
# Doing SKOP
# -------------------------------
# Doing SLy
# -------------------------------
# ...
